# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta,date

# %%
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',100)

# %%
# Load the origianl file in csv format

df = pd.read_csv('Orig_data.csv',error_bad_lines=False)
df.head()
# Out:
#   Channel        Date                            DCM Campaign Name   Market  \
# 0  Social  09/09/2018  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684  Germany
# 1  Social  10/09/2018  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684  Germany
# 2  Social  11/09/2018  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684  Germany
# 3  Social  12/09/2018  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684  Germany
# 4  Social  13/09/2018  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684  Germany
#
#    GEP    KPI      Site    Ad Type  DCM Placement ID  \
# 0  AZR  Trial  Facebook  Canvas Ad         224009494
# 1  AZR  Trial  Facebook  Canvas Ad         224009494
# 2  AZR  Trial  Facebook  Canvas Ad         224009494
# 3  AZR  Trial  Facebook  Canvas Ad         224009494
# 4  AZR  Trial  Facebook  Canvas Ad         224009494
#
#                                       Placement Name  Publisher Impressions  \
# 0  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...                 8009.0
# 1  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...                20102.0
# 2  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...                20832.0
# 3  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...                11509.0
# 4  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...                13274.0
#
#    Publisher Clicks  Net Media Cost Currency  Lead Form Ad Leads
# 0              38.0          134.53      EUR                 NaN
# 1              44.0          145.47      EUR                 NaN
# 2              53.0          199.72      EUR                 NaN
# 3              30.0          111.20      EUR                 NaN
# 4              31.0          110.62      EUR                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 15 columns):
# Channel                  769 non-null object
# Date                     769 non-null object
# DCM Campaign Name        769 non-null object
# Market                   769 non-null object
# GEP                      769 non-null object
# KPI                      769 non-null object
# Site                     769 non-null object
# Ad Type                  769 non-null object
# DCM Placement ID         769 non-null int64
# Placement Name           769 non-null object
# Publisher Impressions    769 non-null float64
# Publisher Clicks         346 non-null float64
# Net Media Cost           769 non-null float64
# Currency                 769 non-null object
# Lead Form Ad Leads       189 non-null float64
# dtypes: float64(4), int64(1), object(10)
# memory usage: 90.2+ KB

# %%
df['Publisher Clicks'].fillna(0, inplace=True)

# %%
df = df.drop(['Lead Form Ad Leads'],axis=1)

# %%
df.columns
# Out:
# Index(['Channel', 'Date', 'DCM Campaign Name', 'Market', 'GEP', 'KPI', 'Site',
#        'Ad Type', 'DCM Placement ID', 'Placement Name',
#        'Publisher Impressions', 'Publisher Clicks', 'Net Media Cost',
#        'Currency'],
#       dtype='object')

# %% [markdown]
# # Make a new dataframe

# %%
columns = ['Lookup Key 1','Lookup Key 2', 'Source', 'Weekend Date','Clean Market','Clean Ad Type','Campaign Name ID','Campaign ID','Campaign External ID','Clean Publisher','Site ID','Creative Name','Creative ID']
new_df = pd.DataFrame(columns=columns)
new_df
# Out:
# Empty DataFrame
# Columns: [Lookup Key 1, Lookup Key 2, Source, Weekend Date, Clean Market, Clean Ad Type, Campaign Name ID, Campaign ID, Campaign External ID, Clean Publisher, Site ID, Creative Name, Creative ID]
# Index: []

# %%
def date_to_key(date_row):
    return str((datetime.strptime(date_row, "%d/%m/%Y").date()- date(1900,1,1)).days + 2)

# %%
new_df['Lookup Key 1'] = df['Date'].apply(date_to_key) + df['DCM Placement ID'].astype(str) 
new_df['Lookup Key 2'] = df['Date'].apply(date_to_key) + df['Placement Name'].astype(str)

# %%
new_df['Source'] = "Appended from Pub-Facebook"

# %%
def get_weekend_date(date):
    return (datetime.strptime(date, "%d/%m/%Y").date() + timedelta(6 - datetime.strptime(date, "%d/%m/%Y").date().weekday())).strftime('%d-%m-%Y')

new_df['Weekend Date'] = df['Date'].apply(get_weekend_date)

# %%
new_df['Clean Publisher'] = "Look at taxonomy"
new_df.loc[(df.apply(lambda x: "FACEBOOK" in x['Placement Name'].upper(), axis=1)),"Clean Publisher"] = "Facebook"
new_df.loc[(df.apply(lambda x: "INSTAGRAM" in x['Placement Name'].upper(), axis=1)),"Clean Publisher"] = "Facebook-Instagram"

# %%
new_df['Site ID']  = "Not Facebook"
new_df.loc[new_df['Clean Publisher']=="Facebook", 'Site ID'] = "3654128"

# %%
new_df['Clean Ad Type'] = "Not filled properly"
new_df.loc[(df.apply(lambda x: "canvas" in x['Ad Type'].lower(), axis=1)),"Clean Ad Type"] = "Link"
new_df.loc[(df.apply(lambda x: "link" in x['Ad Type'].lower(), axis=1)),"Clean Ad Type"] = "Link"

# %%
key = pd.read_csv('key.csv',skiprows=4)
key = key.drop(['Unnamed: 0','Unnamed: 4','Unnamed: 7','Unnamed: 10'],axis=1)
key.head()
# Out:
#       Market Clean Market         Region   Ad Type Clean Ad Type    KPI  \
# 0         AU    Australia           APAC      Link          Link  Leads
# 1        AUS    Australia           APAC   Link Ad          Link    CPC
# 2  Australia    Australia           APAC  Link Ads          Link   Lead
# 3         CA       Canada  North America      Lead          Lead    NaN
# 4        CAN       Canada  North America   Lead Ad          Lead    NaN
#
#   Clean KPI                Site Clean Publisher
# 0      Lead            LinkedIn        LinkedIn
# 1      Lead            Facebook        Facebook
# 2      Lead        Facebook Inc        Facebook
# 3       NaN  Facebook Lead Form        Facebook
# 4       NaN                 NaN             NaN

# %%
market_dict = pd.Series(key['Clean Market'].values,index=key.Market.values).to_dict()
new_df['Clean Market'] = df['Market']
new_df['Clean Market'].replace(market_dict, inplace=True)

# %%
new_df.head()
# Out:
#      Lookup Key 1                                       Lookup Key 2  \
# 0  43352224009494  43352Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 1  43353224009494  43353Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 2  43354224009494  43354Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 3  43355224009494  43355Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 4  43356224009494  43356Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
#
#                        Source Weekend Date Clean Market Clean Ad Type  \
# 0  Appended from Pub-Facebook   09-09-2018      Germany          Link
# 1  Appended from Pub-Facebook   16-09-2018      Germany          Link
# 2  Appended from Pub-Facebook   16-09-2018      Germany          Link
# 3  Appended from Pub-Facebook   16-09-2018      Germany          Link
# 4  Appended from Pub-Facebook   16-09-2018      Germany          Link
#
#   Campaign Name ID Campaign ID Campaign External ID Clean Publisher  Site ID  \
# 0              NaN         NaN                  NaN        Facebook  3654128
# 1              NaN         NaN                  NaN        Facebook  3654128
# 2              NaN         NaN                  NaN        Facebook  3654128
# 3              NaN         NaN                  NaN        Facebook  3654128
# 4              NaN         NaN                  NaN        Facebook  3654128
#
#   Creative Name Creative ID
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN

# %%
lookup = pd.read_csv('lookup.csv',encoding='latin1')
lookup.head()
# Out:
#                                       Placement Name  Placement ID  \
# 0  FacebookÂ»AZP-Canvas-Interest&Role-TrialÂ»1x1Â...     223298805
# 1  FacebookÂ»AZP-Canvas-Interest&Role-TrialÂ»1x1Â...     223298805
# 2  FacebookÂ»AZP-Canvas-Look a Like-TrialÂ»1x1Â»C...     223297413
# 3  FacebookÂ»Audience & Interest TargetingÂ»1x1Â»...     224639151
# 4  FacebookÂ»Audience & Interest TargetingÂ»1x1Â»...     224639151
#
#                           Campaign Name  Campaign ID  Campaign External ID  \
# 0  JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social     21276694                720195
# 1  JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social     21276694                720195
# 2  JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social     21276694                720195
# 3  AUS_gaPMG_AZR_AZR_Q1_19_Trial-Social     21358568                720191
# 4  AUS_gaPMG_AZR_AZR_Q1_19_Trial-Social     21358568                720191
#
#   Publisher  Site ID                                      Creative Name  \
# 0  Facebook  3654128  AzurePlatform_FBCTCcanvaspage-BuyNowCTA-Img3_J...
# 1  Facebook  3654128  AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img...
# 2  Facebook  3654128  AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img...
# 3  Facebook  3654128  AzurePlatform_FBCTCcanvaspage-BuyNowCTA-Img3_A...
# 4  Facebook  3654128  AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img...
#
#    Creative ID
# 0    102630373
# 1    102609621
# 2    102609621
# 3    103316832
# 4    103316829

# %%
new_df['Campaign Name ID'] = df['DCM Placement ID']
lookup_Campaign_dict = pd.Series(lookup['Campaign Name'].values,index=lookup['Placement ID'].values).to_dict()
new_df['Campaign Name ID'].replace(lookup_Campaign_dict, inplace=True)

# %%
new_df['Campaign ID'] = new_df['Campaign Name ID']
lookup_Campaign_id_dict = pd.Series(lookup['Campaign ID'].values,index=lookup['Campaign Name'].values).to_dict()
new_df['Campaign ID'].replace(lookup_Campaign_id_dict,inplace=True)

# %%
new_df['Campaign External ID'] = new_df['Campaign Name ID']
lookup_Campaign_external_id_dict = pd.Series(lookup['Campaign External ID'].values,index=lookup['Campaign Name'].values).to_dict()
new_df['Campaign External ID'].replace(lookup_Campaign_external_id_dict,inplace=True)

# %%
new_df['Creative Name'] = new_df['Campaign Name ID']
lookup_Creative_name_dict = pd.Series(lookup['Creative Name'].values,index=lookup['Campaign Name'].values).to_dict()
new_df['Creative Name'].replace(lookup_Creative_name_dict,inplace=True)

# %%
new_df['Creative ID'] = new_df['Campaign Name ID']
lookup_Creative_id_dict = pd.Series(lookup['Creative ID'].values,index=lookup['Campaign Name'].values).to_dict()
new_df['Creative ID'].replace(lookup_Creative_id_dict,inplace=True)

# %%
new_df['Publisher Impressions'] = df['Publisher Impressions']

new_df['Publisher Clicks'] = df['Publisher Clicks']

new_df['Net Media Cost'] = df['Net Media Cost']

new_df['Date'] = df['Date']

new_df['Placement Name'] = df['Placement Name']

new_df['DCM Placement ID'] = df['DCM Placement ID']

new_df['Publisher Clicks'] = df['Publisher Clicks']

# %%
new_df.head()
# Out:
#      Lookup Key 1                                       Lookup Key 2  \
# 0  43352224009494  43352Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 1  43353224009494  43353Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 2  43354224009494  43354Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 3  43355224009494  43355Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 4  43356224009494  43356Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
#
#                        Source Weekend Date Clean Market Clean Ad Type  \
# 0  Appended from Pub-Facebook   09-09-2018      Germany          Link
# 1  Appended from Pub-Facebook   16-09-2018      Germany          Link
# 2  Appended from Pub-Facebook   16-09-2018      Germany          Link
# 3  Appended from Pub-Facebook   16-09-2018      Germany          Link
# 4  Appended from Pub-Facebook   16-09-2018      Germany          Link
#
#                               Campaign Name ID  Campaign ID  \
# 0  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 1  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 2  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 3  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 4  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
#
#    Campaign External ID Clean Publisher  Site ID  \
# 0                720194        Facebook  3654128
# 1                720194        Facebook  3654128
# 2                720194        Facebook  3654128
# 3                720194        Facebook  3654128
# 4                720194        Facebook  3654128
#
#                                        Creative Name  Creative ID  \
# 0  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 1  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 2  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 3  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 4  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
#
#    Publisher Impressions  Publisher Clicks  Net Media Cost        Date  \
# 0                 8009.0              38.0          134.53  09/09/2018
# 1                20102.0              44.0          145.47  10/09/2018
# 2                20832.0              53.0          199.72  11/09/2018
# 3                11509.0              30.0          111.20  12/09/2018
# 4                13274.0              31.0          110.62  13/09/2018
#
#                                       Placement Name  DCM Placement ID
# 0  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 1  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 2  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 3  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 4  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494

# %%
#new_df.to_csv('new_df.csv',index=False)

# %%
all_cols = ["Lookup Key 1", "Lookup Key 2", "Source", 'Date', "Campaign Name ID", "Campaign ID",
"Campaign External ID","Clean Publisher","Site ID","Placement Name","DCM Placement ID",
"Creative Name","Creative ID","Publisher Impressions","Net Media Cost"]

# %%
pivot_df = new_df[all_cols]

# %%
pivot_df.head()
# Out:
#      Lookup Key 1                                       Lookup Key 2  \
# 0  43352224009494  43352Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 1  43353224009494  43353Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 2  43354224009494  43354Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 3  43355224009494  43355Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
# 4  43356224009494  43356Facebook»DEV-ITP-AZR-FB|CanvasAds|Interes...
#
#                        Source        Date  \
# 0  Appended from Pub-Facebook  09/09/2018
# 1  Appended from Pub-Facebook  10/09/2018
# 2  Appended from Pub-Facebook  11/09/2018
# 3  Appended from Pub-Facebook  12/09/2018
# 4  Appended from Pub-Facebook  13/09/2018
#
#                               Campaign Name ID  Campaign ID  \
# 0  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 1  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 2  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 3  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
# 4  DEU_gaPMG_AZR_AZR_Q1_19_Trial-Social- 39684     21359477
#
#    Campaign External ID Clean Publisher  Site ID  \
# 0                720194        Facebook  3654128
# 1                720194        Facebook  3654128
# 2                720194        Facebook  3654128
# 3                720194        Facebook  3654128
# 4                720194        Facebook  3654128
#
#                                       Placement Name  DCM Placement ID  \
# 0  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 1  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 2  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 3  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
# 4  Facebook»DEV-ITP-AZR-FB|CanvasAds|Interesttarg...         224009494
#
#                                        Creative Name  Creative ID  \
# 0  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 1  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 2  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 3  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
# 4  AzurePlatform_FBCTCBrandinMotion-BuyNow_DEU_12...    103350059
#
#    Publisher Impressions  Net Media Cost
# 0                 8009.0          134.53
# 1                20102.0          145.47
# 2                20832.0          199.72
# 3                11509.0          111.20
# 4                13274.0          110.62

# %%
p_table = pd.pivot_table(pivot_df,index=["Lookup Key 1","Lookup Key 2","Source", 'Date', "Campaign Name ID", "Campaign ID",
                                "Campaign External ID","Clean Publisher","Site ID","Placement Name",
                               "DCM Placement ID","Creative Name","Creative ID"],values=["Net Media Cost","Publisher Impressions"],aggfunc=np.sum)

# %%
p_table.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                           Net Media Cost  \
# Lookup Key 1   Lookup Key 2                                       Source                     Date       Campaign Name ID                     Campaign ID Campaign External ID Clean Publisher Site ID Placement Name                                     DCM Placement ID Creative Name                                      Creative ID
# 43352223297413 43352Facebook»AZP-Canvas-Look a Like-Trial»1x1»... Appended from Pub-Facebook 09/09/2018 JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social 21276694    720195               Facebook        3654128 Facebook»AZP-Canvas-Look a Like-Trial»1x1»Canva... 223297413        AZR_FBCTCcanvaspage-BuyNowCTA-Img3_JPN_1080x162... 104060547            2170.0
# 43352223298805 43352Facebook»AZP-Canvas-Interest&Role-Trial»1x... Appended from Pub-Facebook 09/09/2018 JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social 21276694    720195               Facebook        3654128 Facebook»AZP-Canvas-Interest&Role-Trial»1x1»Can... 223298805        AZR_FBCTCcanvaspage-BuyNowCTA-Img3_JPN_1080x162... 104060547            9290.0
# 43352223560299 43352Facebook»Retargeting»1x1»SocialBan»LIA»DT»... Appended from Pub-Facebook 09/09/2018 GBR_gaPMG_CE_AZR_Q1_19_Trial-Social  21337013    720196               Facebook        3654128 Facebook»Retargeting»1x1»SocialBan»LIA»DT»DYN»R... 223560299        AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img2... 103235146              13.4
# 43352223560332 43352Facebook»Retargeting»1x1»SocialBan»LIA»DT»... Appended from Pub-Facebook 09/09/2018 GBR_gaPMG_CE_AZR_Q1_19_Trial-Social  21337013    720196               Facebook        3654128 Facebook»Retargeting»1x1»SocialBan»LIA»DT»DYN»R... 223560332        AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img2... 103235146              13.4
# 43352223560338 43352Facebook»Retargeting»1x1»SocialBan»LIA»DT»... Appended from Pub-Facebook 09/09/2018 GBR_gaPMG_CE_AZR_Q1_19_Trial-Social  21337013    720196               Facebook        3654128 Facebook»Retargeting»1x1»SocialBan»LIA»DT»DYN»R... 223560338        AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img2... 103235146              13.4
#
#                                                                                                                                                                                                                                                                                                                                           Publisher Impressions
# Lookup Key 1   Lookup Key 2                                       Source                     Date       Campaign Name ID                     Campaign ID Campaign External ID Clean Publisher Site ID Placement Name                                     DCM Placement ID Creative Name                                      Creative ID
# 43352223297413 43352Facebook»AZP-Canvas-Look a Like-Trial»1x1»... Appended from Pub-Facebook 09/09/2018 JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social 21276694    720195               Facebook        3654128 Facebook»AZP-Canvas-Look a Like-Trial»1x1»Canva... 223297413        AZR_FBCTCcanvaspage-BuyNowCTA-Img3_JPN_1080x162... 104060547                  2507.00
# 43352223298805 43352Facebook»AZP-Canvas-Interest&Role-Trial»1x... Appended from Pub-Facebook 09/09/2018 JPN_gaPMG_AZR_AZR_Q1_19_Trial-Social 21276694    720195               Facebook        3654128 Facebook»AZP-Canvas-Interest&Role-Trial»1x1»Can... 223298805        AZR_FBCTCcanvaspage-BuyNowCTA-Img3_JPN_1080x162... 104060547                  7306.00
# 43352223560299 43352Facebook»Retargeting»1x1»SocialBan»LIA»DT»... Appended from Pub-Facebook 09/09/2018 GBR_gaPMG_CE_AZR_Q1_19_Trial-Social  21337013    720196               Facebook        3654128 Facebook»Retargeting»1x1»SocialBan»LIA»DT»DYN»R... 223560299        AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img2... 103235146                   514.92
# 43352223560332 43352Facebook»Retargeting»1x1»SocialBan»LIA»DT»... Appended from Pub-Facebook 09/09/2018 GBR_gaPMG_CE_AZR_Q1_19_Trial-Social  21337013    720196               Facebook        3654128 Facebook»Retargeting»1x1»SocialBan»LIA»DT»DYN»R... 223560332        AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img2... 103235146                   514.92
# 43352223560338 43352Facebook»Retargeting»1x1»SocialBan»LIA»DT»... Appended from Pub-Facebook 09/09/2018 GBR_gaPMG_CE_AZR_Q1_19_Trial-Social  21337013    720196               Facebook        3654128 Facebook»Retargeting»1x1»SocialBan»LIA»DT»DYN»R... 223560338        AzurePlatform_FBCTCcanvaspage-StartFreeCTA-Img2... 103235146                   514.92

# %%
#p_table.to_csv('pivot_table.csv')

# %%
new_df.columns
# Out:
# Index(['Lookup Key 1', 'Lookup Key 2', 'Source', 'Weekend Date',
#        'Clean Market', 'Clean Ad Type', 'Campaign Name ID', 'Campaign ID',
#        'Campaign External ID', 'Clean Publisher', 'Site ID', 'Creative Name',
#        'Creative ID', 'Publisher Impressions', 'Publisher Clicks',
#        'Net Media Cost', 'Date', 'Placement Name', 'DCM Placement ID'],
#       dtype='object')

# %%
p_table2 = pd.pivot_table(new_df,index=['Clean Market','Clean Publisher','Clean Ad Type'],values=['Publisher Impressions','Publisher Clicks','Net Media Cost'],aggfunc=np.sum)

# %%
p_table2
# Out:
#                                               Net Media Cost  \
# Clean Market   Clean Publisher Clean Ad Type
# Canada         Facebook        Link                  6444.16
# France         Facebook        Link                  1216.10
# Germany        Facebook        Link                  1564.43
# Japan          Facebook        Link                140000.00
# United Kingdom Facebook        Link                  2534.98
#
#                                               Publisher Clicks  \
# Clean Market   Clean Publisher Clean Ad Type
# Canada         Facebook        Link                      703.0
# France         Facebook        Link                     2603.0
# Germany        Facebook        Link                      591.0
# Japan          Facebook        Link                      541.0
# United Kingdom Facebook        Link                      141.0
#
#                                               Publisher Impressions
# Clean Market   Clean Publisher Clean Ad Type
# Canada         Facebook        Link                       291735.00
# France         Facebook        Link                       174941.00
# Germany        Facebook        Link                       142221.00
# Japan          Facebook        Link                       126731.00
# United Kingdom Facebook        Link                       161971.96

# %%
p_table2['Net Media Cost'].sum()
# Out:
# 151759.67

# %%
p_table2['Publisher Clicks'].sum()
# Out:
# 4579.0

# %%
p_table2['Publisher Impressions'].sum()
# Out:
# 897599.9600000001
